# %%
import nltk
from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.tokenize import TreebankWordTokenizer
from nltk.tag import pos_tag
from nltk import ne_chunk, Tree
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
nltk.download('maxent_ne_chunker')
nltk.download('words')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\郭洸丞\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\郭洸丞\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package maxent_ne_chunker to
# [nltk_data]     C:\Users\郭洸丞\AppData\Roaming\nltk_data...
# [nltk_data]   Package maxent_ne_chunker is already up-to-date!
# [nltk_data] Downloading package words to
# [nltk_data]     C:\Users\郭洸丞\AppData\Roaming\nltk_data...
# [nltk_data]   Package words is already up-to-date!
# True

# %%
f = open('./path/news.txt','r')
ex = f.readlines()
f.close()
len(ex)
# Out:
# 58

# %%
strEx = " ".join(str(x) for x in ex)

# %%
def preprocess(sent):
    sent = nltk.word_tokenize(sent)
    sent = nltk.pos_tag(sent)
    return sent

# %%
sent = preprocess(strEx)
sent
# Out:
# [('Taiwan', 'NNP'),
#  ('voters', 'NNS'),
#  ('reject', 'VBP'),
#  ('same-sex', 'JJ'),
#  ('marriage', 'NN'),
#  ('By', 'IN'),
#  ('Hira', 'NNP'),
#  ('Humayun', 'NNP'),
#  ('and', 'CC'),
#  ('Susannah', 'NNP'),
#  ('Cullinane', 'NNP'),
#  ('Updated', 'VBD'),
#  ('0801', 'CD'),
#  ('GMT', 'NNP'),
#  ('(', '('),
#  ('1601', 'CD'),
#  ('HKT', 'NNP'),
#  (')', ')'),
#  ('November', 'NNP'),
#  ('25', 'CD'),
#  (',', ','),
#  ('2018', 'CD'),
#  ('Same-sex', 'JJ'),
#  ('activists', 'NNS'),
#  ('hug', 'VBD'),
#  ('outside', 'IN'),
#  ('the', 'DT'),
#  ('parliament', 'NN'),
#  ('in', 'IN'),
#  ('Taipei', 'NNP'),
#  ('on', 'IN'),
#  ('May', 'NNP'),
#  ('24', 'CD'),
#  (',', ','),
#  ('2017', 'CD'),
#  ('as', 'IN'),
#  ('they', 'PRP'),
#  ('celebrate', 'VBP'),
#  ('the', 'DT'),
#  ('landmark', 'NN'),
#  ('decision', 'NN'),
#  ('paving', 'VBG'),
#  ('the', 'DT'),
#  ('way', 'NN'),
#  ('for', 'IN'),
#  ('the', 'DT'),
#  ('island', 'NN'),
#  ('to', 'TO'),
#  ('become', 'VB'),
#  ('the', 'DT'),
#  ('first', 'JJ'),
#  ('place', 'NN'),
#  ('in', 'IN'),
#  ('Asia', 'NNP'),
#  ('to', 'TO'),
#  ('legalise', 'VB'),
#  ('gay', 'JJ'),
#  ('marriage', 'NN'),
#  ('.', '.'),
#  ('Crowds', 'NNP'),
#  ('of', 'IN'),
#  ('pro-gay', 'JJ'),
#  ('marriage', 'NN'),
#  ('supporters', 'NNS'),
#  ('in', 'IN'),
#  ('Taiwan', 'NNP'),
#  ('on', 'IN'),
#  ('May', 'NNP'),
#  ('24', 'CD'),
#  ('cheered', 'VBD'),
#  (',', ','),
#  ('hugged', 'VBD'),
#  ('and', 'CC'),
#  ('wept', 'VBD'),
#  ('as', 'IN'),
#  ('a', 'DT'),
#  ('top', 'JJ'),
#  ('court', 'NN'),
#  ('ruled', 'VBD'),
#  ('in', 'IN'),
#  ('favour', 'NN'),
#  ('of', 'IN'),
#  ('same-sex', 'JJ'),
#  ('unions', 'NNS'),
#  ('.', '.'),
#  ('/', 'JJ'),
#  ('AFP', 'NNP'),
#  ('PHOTO', 'NNP'),
#  ('/', 'NNP'),
#  ('SAM', 'NNP'),
#  ('YEH', 'NNP'),
#  ('(', '('),
#  ('Photo', 'NNP'),
#  ('credit', 'NN'),
#  ('should', 'MD'),
#  ('read', 'VB'),
#  ('SAM', 'NNP'),
#  ('YEH/AFP/Getty', 'NNP'),
#  ('Images', 'NNP'),
#  (')', ')'),
#  ('Three', 'NNP'),
#  ('referendum', 'NN'),
#  ('questions', 'NNS'),
#  ('initiated', 'VBN'),
#  ('by', 'IN'),
#  ('groups', 'NNS'),
#  ('that', 'WDT'),
#  ('opposed', 'VBD'),
#  ('marriage', 'NN'),
#  ('equality', 'NN'),
#  ('passed', 'VBD'),
#  (',', ','),
#  ('while', 'IN'),
#  ('those', 'DT'),
#  ('put', 'VBN'),
#  ('forth', 'RB'),
#  ('by', 'IN'),
#  ('same-sex', 'JJ'),
#  ('marriage', 'NN'),
#  ('advocates', 'NNS'),
#  ('did', 'VBD'),
#  ('not', 'RB'),
#  ('.', '.'),
#  ('For', 'IN'),
#  ('instance', 'NN'),
#  (',', ','),
#  ('the', 'DT'),
#  ('majority', 'NN'),
#  ('vote', 'NN'),
#  ('was', 'VBD'),
#  ('yes', 'RB'),
#  ('on', 'IN'),
#  ('a', 'DT'),
#  ('question', 'NN'),
#  ('that', 'WDT'),
#  ('asked', 'VBD'),
#  (',', ','),
#  ('``', '``'),
#  ('Do', 'VBP'),
#  ('you', 'PRP'),
#  ('agree', 'VB'),
#  ('that', 'IN'),
#  ('Civil', 'NNP'),
#  ('Code', 'NNP'),
#  ('regulations', 'NNS'),
#  ('should', 'MD'),
#  ('restrict', 'VB'),
#  ('marriage', 'NN'),
#  ('to', 'TO'),
#  ('being', 'VBG'),
#  ('between', 'IN'),
#  ('a', 'DT'),
#  ('man', 'NN'),
#  ('and', 'CC'),
#  ('a', 'DT'),
#  ('woman', 'NN'),
#  ('?', '.'),
#  ("''", "''"),
#  ('Voters', 'NNPS'),
#  (',', ','),
#  ('meanwhile', 'RB'),
#  (',', ','),
#  ('rejected', 'VBD'),
#  ('a', 'DT'),
#  ('question', 'NN'),
#  ('put', 'VBD'),
#  ('forth', 'NN'),
#  ('by', 'IN'),
#  ('LGBT', 'NNP'),
#  ('activists', 'NNS'),
#  ('that', 'WDT'),
#  ('asked', 'VBD'),
#  ('if', 'IN'),
#  ('civil', 'JJ'),
#  ('code', 'NN'),
#  ('marriage', 'NN'),
#  ('regulations', 'NNS'),
#  ('``', '``'),
#  ('should', 'MD'),
#  ('be', 'VB'),
#  ('used', 'VBN'),
#  ('to', 'TO'),
#  ('guarantee', 'VB'),
#  ('the', 'DT'),
#  ('rights', 'NNS'),
#  ('of', 'IN'),
#  ('same-sex', 'NN'),
#  ('couples', 'NNS'),
#  ('to', 'TO'),
#  ('get', 'VB'),
#  ('married', 'JJ'),
#  ('.', '.'),
#  ("''", "''"),
#  ('Amnesty', 'NNP'),
#  ('International', 'NNP'),
#  ('Taiwan', 'NNP'),
#  ("'s", 'POS'),
#  ('Acting', 'NNP'),
#  ('Director', 'NNP'),
#  ('Annie', 'NNP'),
#  ('Huang', 'NNP'),
#  ('called', 'VBD'),
#  ('the', 'DT'),
#  ('result', 'NN'),
#  ('``', '``'),
#  ('a', 'DT'),
#  ('bitter', 'JJ'),
#  ('blow', 'NN'),
#  ('and', 'CC'),
#  ('a', 'DT'),
#  ('step', 'NN'),
#  ('backwards', 'NNS'),
#  ('for', 'IN'),
#  ('human', 'JJ'),
#  ('rights', 'NNS'),
#  ("''", "''"),
#  ('on', 'IN'),
#  ('the', 'DT'),
#  ('island', 'NN'),
#  ('.', '.'),
#  ('``', '``'),
#  ('However', 'RB'),
#  (',', ','),
#  ('despite', 'IN'),
#  ('this', 'DT'),
#  ('setback', 'NN'),
#  (',', ','),
#  ('we', 'PRP'),
#  ('remain', 'VBP'),
#  ('confident', 'JJ'),
#  ('that', 'IN'),
#  ('love', 'NN'),
#  ('and', 'CC'),
#  ('equality', 'NN'),
#  ('will', 'MD'),
#  ('ultimately', 'RB'),
#  ('prevail', 'VB'),
#  (',', ','),
#  ("''", "''"),
#  ('Huang', 'NNP'),
#  ('said', 'VBD'),
#  ('in', 'IN'),
#  ('a', 'DT'),
#  ('statement', 'NN'),
#  ('.', '.'),
#  ('``', '``'),
#  ('The', 'DT'),
#  ('result', 'NN'),
#  ('must', 'MD'),
#  ('not', 'RB'),
#  ('be', 'VB'),
#  ('used', 'VBN'),
#  ('as', 'IN'),
#  ('an', 'DT'),
#  ('excuse', 'NN'),
#  ('to', 'TO'),
#  ('further', 'JJ'),
#  ('undermine', 'VB'),
#  ('the', 'DT'),
#  ('rights', 'NNS'),
#  ('of', 'IN'),
#  ('LGBTI', 'NNP'),
#  ('people', 'NNS'),
#  ('.', '.'),
#  ('The', 'DT'),
#  ('Taiwanese', 'JJ'),
#  ('government', 'NN'),
#  ('needs', 'NNS'),
#  ('to', 'TO'),
#  ('step', 'VB'),
#  ('up', 'RB'),
#  ('and', 'CC'),
#  ('take', 'VB'),
#  ('all', 'DT'),
#  ('necessary', 'JJ'),
#  ('measures', 'NNS'),
#  ('to', 'TO'),
#  ('deliver', 'VB'),
#  ('equality', 'NN'),
#  ('and', 'CC'),
#  ('dignity', 'NN'),
#  ('for', 'IN'),
#  ('all', 'DT'),
#  (',', ','),
#  ('regardless', 'RB'),
#  ('of', 'IN'),
#  ('who', 'WP'),
#  ('people', 'NNS'),
#  ('love', 'VBP'),
#  ('.', '.'),
#  ("''", "''"),
#  ('High', 'JJ'),
#  ('court', 'NN'),
#  ('ruled', 'VBD'),
#  ('in', 'IN'),
#  ('favor', 'NN'),
#  ('of', 'IN'),
#  ('same-sex', 'JJ'),
#  ('marriage', 'NN'),
#  ('The', 'DT'),
#  ('vote', 'NN'),
#  ('comes', 'VBZ'),
#  ('after', 'IN'),
#  ('Taiwan', 'NNP'),
#  ("'s", 'POS'),
#  ('high', 'JJ'),
#  ('court', 'NN'),
#  ('passed', 'VBD'),
#  ('a', 'DT'),
#  ('resolution', 'NN'),
#  ('in', 'IN'),
#  ('May', 'NNP'),
#  ('2017', 'CD'),
#  ('ruling', 'VBG'),
#  ('it', 'PRP'),
#  ('was', 'VBD'),
#  ('unconstitutional', 'JJ'),
#  ('to', 'TO'),
#  ('ban', 'VB'),
#  ('same-sex', 'JJ'),
#  ('couples', 'NNS'),
#  ('from', 'IN'),
#  ('getting', 'VBG'),
#  ('married', 'VBN'),
#  ('.', '.'),
#  ('The', 'DT'),
#  ('ruling', 'NN'),
#  ('was', 'VBD'),
#  ('seen', 'VBN'),
#  ('as', 'IN'),
#  ('a', 'DT'),
#  ('rare', 'JJ'),
#  ('beam', 'NN'),
#  ('of', 'IN'),
#  ('light', 'NN'),
#  ('in', 'IN'),
#  ('a', 'DT'),
#  ('region', 'NN'),
#  ('infamous', 'JJ'),
#  ('for', 'IN'),
#  ('its', 'PRP$'),
#  ('repression', 'NN'),
#  ('of', 'IN'),
#  ('LGBT', 'NNP'),
#  ('people', 'NNS'),
#  ('.', '.'),
#  ('The', 'DT'),
#  ('ruling', 'NN'),
#  ('gave', 'VBD'),
#  ('Taiwanese', 'JJ'),
#  ('lawmakers', 'NNS'),
#  ('a', 'DT'),
#  ('two-year', 'JJ'),
#  ('deadline', 'NN'),
#  ('to', 'TO'),
#  ('enshrine', 'VB'),
#  ('marriage', 'NN'),
#  ('equality', 'NN'),
#  ('into', 'IN'),
#  ('law', 'NN'),
#  (',', ','),
#  ('but', 'CC'),
#  ('the', 'DT'),
#  ('government', 'NN'),
#  ('reached', 'VBD'),
#  ('a', 'DT'),
#  ('deadlock', 'NN'),
#  ('.', '.'),
#  ('With', 'IN'),
#  ('the', 'DT'),
#  ('government', 'NN'),
#  ('stuck', 'NN'),
#  (',', ','),
#  ('Taiwan', 'NNP'),
#  ("'s", 'POS'),
#  ('conservatives', 'NNS'),
#  ('saw', 'VBD'),
#  ('an', 'DT'),
#  ('opportunity', 'NN'),
#  ('to', 'TO'),
#  ('use', 'VB'),
#  ('the', 'DT'),
#  ('newly', 'RB'),
#  ('revised', 'VBN'),
#  ('referendum', 'NN'),
#  ('law', 'NN'),
#  ('--', ':'),
#  ('under', 'IN'),
#  ('which', 'WDT'),
#  ('any', 'DT'),
#  ('suggested', 'VBD'),
#  ('question', 'NN'),
#  ('that', 'IN'),
#  ('gets', 'VBZ'),
#  ('a', 'DT'),
#  ('minimum', 'NN'),
#  ('of', 'IN'),
#  ('280,000', 'CD'),
#  ('signatures', 'NNS'),
#  ('must', 'MD'),
#  ('be', 'VB'),
#  ('put', 'VBN'),
#  ('to', 'TO'),
#  ('the', 'DT'),
#  ('people', 'NNS'),
#  ('--', ':'),
#  ('to', 'TO'),
#  ('stall', 'VB'),
#  ('same-sex', 'JJ'),
#  ('marriage', 'NN'),
#  ('.', '.'),
#  ('Legal', 'NNP'),
#  ('confusion', 'NN'),
#  ('Saturday', 'NNP'),
#  ("'s", 'POS'),
#  ('results', 'NNS'),
#  ('mean', 'VBP'),
#  ('that', 'IN'),
#  ('Taiwan', 'NNP'),
#  ("'s", 'POS'),
#  ('government', 'NN'),
#  ('could', 'MD'),
#  ('now', 'RB'),
#  ('be', 'VB'),
#  ('compelled', 'VBN'),
#  ('to', 'TO'),
#  ('enforce', 'VB'),
#  ('a', 'DT'),
#  ('law', 'NN'),
#  ('already', 'RB'),
#  ('ruled', 'VBD'),
#  ('unconstitutional', 'JJ'),
#  ('.', '.'),
#  ('Further', 'RBR'),
#  ('complicating', 'VBG'),
#  ('matters', 'NNS'),
#  (',', ','),
#  ('there', 'EX'),
#  ('remains', 'VBZ'),
#  ('broad', 'JJ'),
#  ('disagreement', 'NN'),
#  ('among', 'IN'),
#  ('legal', 'JJ'),
#  ('experts', 'NNS'),
#  ('on', 'IN'),
#  ('whether', 'IN'),
#  ('President', 'NNP'),
#  ('Tsai', 'NNP'),
#  ('Ing-wen', 'NNP'),
#  ("'s", 'POS'),
#  ('administration', 'NN'),
#  ('is', 'VBZ'),
#  ('mandated', 'VBN'),
#  ('to', 'TO'),
#  ('enact', 'VB'),
#  ('the', 'DT'),
#  ('result', 'NN'),
#  ('into', 'IN'),
#  ('law', 'NN'),
#  ('.', '.'),
#  ('One', 'CD'),
#  ('lawmaker', 'NN'),
#  ('from', 'IN'),
#  ('the', 'DT'),
#  ('president', 'NN'),
#  ("'s", 'POS'),
#  ('Democratic', 'NNP'),
#  ('Progressive', 'NNP'),
#  ('Party', 'NNP'),
#  ('told', 'VBD'),
#  ('CNN', 'NNP'),
#  ('any', 'DT'),
#  ('positive', 'JJ'),
#  ('result', 'NN'),
#  ('``', '``'),
#  ('must', 'MD'),
#  ('pass', 'VB'),
#  ("''", "''"),
#  ('in', 'IN'),
#  ('the', 'DT'),
#  ('next', 'JJ'),
#  ('legislative', 'JJ'),
#  ('session', 'NN'),
#  (',', ','),
#  ('but', 'CC'),
#  ('a', 'DT'),
#  ('legal', 'JJ'),
#  ('expert', 'NN'),
#  ('insisted', 'VBD'),
#  ('it', 'PRP'),
#  ('was', 'VBD'),
#  ('``', '``'),
#  ('up', 'RB'),
#  ('to', 'TO'),
#  ('lawmakers', 'NNS'),
#  ("''", "''"),
#  ('how', 'WRB'),
#  ('they', 'PRP'),
#  ('dealt', 'VBP'),
#  ('with', 'IN'),
#  ('the', 'DT'),
#  ('result', 'NN'),
#  ('.', '.'),
#  ('Amnesty', 'NNP'),
#  ("'s", 'POS'),
#  ('regional', 'JJ'),
#  ('campaign', 'NN'),
#  ('manager', 'NN'),
#  ('for', 'IN'),
#  ('Taiwan', 'NNP'),
#  ('Suki', 'NNP'),
#  ('Chung', 'NNP'),
#  ('said', 'VBD'),
#  ('the', 'DT'),
#  ('result', 'NN'),
#  ('should', 'MD'),
#  ('not', 'RB'),
#  ('be', 'VB'),
#  ('used', 'VBN'),
#  ('to', 'TO'),
#  ('undermine', 'VB'),
#  ('LGBT', 'NNP'),
#  ('rights', 'NNS'),
#  ('.', '.'),
#  ('``', '``'),
#  ('The', 'DT'),
#  ('government', 'NN'),
#  ('must', 'MD'),
#  ('legislate', 'VB'),
#  ('for', 'IN'),
#  ('equality', 'NN'),
#  ('of', 'IN'),
#  ('marriage', 'NN'),
#  ('by', 'IN'),
#  ('2019', 'CD'),
#  ('to', 'TO'),
#  ('comply', 'VB'),
#  ('with', 'IN'),
#  ('the', 'DT'),
#  ('Constitutional', 'NNP'),
#  ('Court', 'NNP'),
#  ("'s", 'POS'),
#  ('decision', 'NN'),
#  (',', ','),
#  ("''", "''"),
#  ('Chung', 'NNP'),
#  ('said', 'VBD'),
#  ('on', 'IN'),
#  ('Twitter', 'NNP'),
#  ('.', '.'),
#  ('Suki', 'NNP'),
#  ('Chung', 'NNP'),
#  ('The', 'DT'),
#  ('result', 'NN'),
#  ('is', 'VBZ'),
#  ('a', 'DT'),
#  ('bitter', 'JJ'),
#  ('blow', 'NN'),
#  ('but', 'CC'),
#  ('it', 'PRP'),
#  ('shouldn', 'VBZ'),
#  ('’', 'JJ'),
#  ('t', 'NN'),
#  ('be', 'VB'),
#  ('used', 'VBN'),
#  ('as', 'IN'),
#  ('an', 'DT'),
#  ('excuse', 'NN'),
#  ('to', 'TO'),
#  ('further', 'JJ'),
#  ('undermine', 'VB'),
#  ('the', 'DT'),
#  ('rights', 'NNS'),
#  ('of', 'IN'),
#  ('#', '#'),
#  ('LGBTI', 'NNP'),
#  ('people', 'NNS'),
#  ('.', '.'),
#  ('The', 'DT'),
#  ('government', 'NN'),
#  ('must', 'MD'),
#  ('legislate', 'VB'),
#  ('for', 'IN'),
#  ('equality', 'NN'),
#  ('of', 'IN'),
#  ('marriage', 'NN'),
#  ('by', 'IN'),
#  ('2019', 'CD'),
#  ('to', 'TO'),
#  ('comply', 'VB'),
#  ('with', 'IN'),
#  ('the', 'DT'),
#  ('Constitutional', 'NNP'),
#  ('Court', 'NNP'),
#  ('’', 'NNP'),
#  ('s', 'POS'),
#  ('decision', 'NN'),
#  ('#', '#'),
#  ('taiwanelection', 'NN'),
#  ('https', 'NN'),
#  (':', ':'),
#  ('//www.amnesty.org/en/latest/news/2018/11/taiwan-referendum-lgbti/', 'JJ'),
#  ('…', 'NNS'),
#  ('Referendum', 'NNP'),
#  ('results', 'NNS'),
#  ('rejecting', 'VBG'),
#  ('marriage', 'NN'),
#  ('equality', 'NN'),
#  ('in', 'IN'),
#  ('Taiwan', 'NNP'),
#  ('a', 'DT'),
#  ('“', 'NNP'),
#  ('bitter', 'NN'),
#  ('blow', 'NN'),
#  ('”', 'NN'),
#  ('Backwards', 'NNP'),
#  ('step', 'NN'),
#  ('for', 'IN'),
#  ('human', 'JJ'),
#  ('rights', 'NNS'),
#  ('as', 'IN'),
#  ('voters', 'NNS'),
#  ('reject', 'VBP'),
#  ('same-sex', 'JJ'),
#  ('marriage', 'NN'),
#  ('rights', 'NNS'),
#  ('and', 'CC'),
#  ('LGBTI-inclusive', 'JJ'),
#  ('education', 'NN'),
#  ('The', 'DT'),
#  ('director', 'NN'),
#  ('of', 'IN'),
#  ('Human', 'NNP'),
#  ('Rights', 'NNP'),
#  ('Watch', 'NNP'),
#  ("'s", 'POS'),
#  ('LGBT', 'NNP'),
#  ('rights', 'NNS'),
#  ('program', 'NN'),
#  (',', ','),
#  ('Graeme', 'NNP'),
#  ('Reid', 'NNP'),
#  (',', ','),
#  ('also', 'RB'),
#  ('called', 'VBD'),
#  ('for', 'IN'),
#  ('the', 'DT'),
#  ('legislation', 'NN'),
#  ('to', 'TO'),
#  ('be', 'VB'),
#  ('enacted', 'VBN'),
#  ('.', '.'),
#  ('``', '``'),
#  ('Disappointing', 'JJ'),
#  ('measure', 'NN'),
#  ('of', 'IN'),
#  ('public', 'JJ'),
#  ('opinion', 'NN'),
#  ('in', 'IN'),
#  ('#', '#'),
#  ('Taiwan', 'NNP'),
#  ('referendum', 'NN'),
#  ('does', 'VBZ'),
#  ('not', 'RB'),
#  ('absolve', 'VB'),
#  ('lawmakers', 'NNS'),
#  ('from', 'IN'),
#  ('enacting', 'VBG'),
#  ('legislation', 'NN'),
#  ('-', ':'),
#  ('per', 'IN'),
#  ('Constitutional', 'NNP'),
#  ('Court', 'NNP'),
#  ('ruling', 'VBG'),
#  ('-', ':'),
#  ('to', 'TO'),
#  ('allow', 'VB'),
#  ('same-sex', 'JJ'),
#  ('partners', 'NNS'),
#  ('to', 'TO'),
#  ('marry', 'VB'),
#  (',', ','),
#  ("''", "''"),
#  ('Reid', 'NNP'),
#  ('tweeted', 'VBD'),
#  ('.', '.'),
#  ('Anti-gay', 'JJ'),
#  ('marriage', 'NN'),
#  ('groups', 'NNS'),
#  ('win', 'VBP'),
#  ('Taiwan', 'NNP'),
#  ('referendum', 'NN'),
#  ('battle', 'NN'),
#  ('Voters', 'NNP'),
#  ('in', 'IN'),
#  ('Taiwan', 'NNP'),
#  ('backed', 'VBD'),
#  ('anti-gay', 'JJ'),
#  ('marriage', 'NN'),
#  ('referendums', 'NNS'),
#  ('Saturday', 'NNP'),
#  ('in', 'IN'),
#  ('what', 'WP'),
#  ('LGBT', 'NNP'),
#  ('activists', 'NNS'),
#  ('said', 'VBD'),
#  ('was', 'VBD'),
#  ('a', 'DT'),
#  ('major', 'JJ'),
#  ('blow', 'NN'),
#  ('to', 'TO'),
#  ('the', 'DT'),
#  ('island', 'NN'),
#  ("'s", 'POS'),
#  ('reputation', 'NN'),
#  ('as', 'IN'),
#  ('a', 'DT'),
#  ('rights', 'NNS'),
#  ('trailblazer', 'NN'),
#  ('.', '.'),
#  ('Asia', 'NNP'),
#  ("'s", 'POS'),
#  ('LGBT', 'NNP'),
#  ('crisis', 'NN'),
#  ('Taiwan', 'NNP'),
#  ('is', 'VBZ'),
#  ('home', 'VBN'),
#  ('to', 'TO'),
#  ('one', 'CD'),
#  ('of', 'IN'),
#  ('Asia', 'NNP'),
#  ("'s", 'POS'),
#  ('largest', 'JJS'),
#  ('and', 'CC'),
#  ('most', 'RBS'),
#  ('vibrant', 'JJ'),
#  ('gay', 'NN'),
#  ('communities', 'NNS'),
#  ('.', '.'),
#  ('Many', 'JJ'),
#  ('of', 'IN'),
#  ('its', 'PRP$'),
#  ('citizens', 'NNS'),
#  ('take', 'VBP'),
#  ('great', 'JJ'),
#  ('pride', 'NN'),
#  ('in', 'IN'),
#  ('the', 'DT'),
#  ('island', 'NN'),
#  ("'s", 'POS'),
#  ('progressive', 'JJ'),
#  (',', ','),
#  ('LGBT-friendly', 'JJ'),
#  ('values', 'NNS'),
#  ('.', '.'),
#  ('If', 'IN'),
#  ('it', 'PRP'),
#  ('had', 'VBD'),
#  ('approved', 'VBN'),
#  ('same-sex', 'JJ'),
#  ('marriage', 'NN'),
#  (',', ','),
#  ('it', 'PRP'),
#  ('would', 'MD'),
#  ('have', 'VB'),
#  ('become', 'VBN'),
#  ('the', 'DT'),
#  ('first', 'JJ'),
#  ('place', 'NN'),
#  ('in', 'IN'),
#  ('Asia', 'NNP'),
#  ('to', 'TO'),
#  ('do', 'VB'),
#  ('so', 'RB'),
#  ('.', '.'),
#  ('Ahead', 'NN'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('vote', 'NN'),
#  (',', ','),
#  ('Human', 'NNP'),
#  ('Rights', 'NNP'),
#  ('Watch', 'NNP'),
#  ('senior', 'JJ'),
#  ('researcher', 'NN'),
#  ('Maya', 'NNP'),
#  ('Wang', 'NNP'),
#  ('said', 'VBD'),
#  ('Taiwan', 'NNP'),
#  ('was', 'VBD'),
#  ('seen', 'VBN'),
#  ('as', 'IN'),
#  ('an', 'DT'),
#  ('inspiration', 'NN'),
#  ('for', 'IN'),
#  ('LGBT', 'NNP'),
#  ('rights', 'NNS'),
#  ('activists', 'NNS'),
#  ('.', '.'),
#  ('``', '``'),
#  ('What', 'WP'),
#  ("'s", 'VBZ'),
#  ('happening', 'VBG'),
#  ('in', 'IN'),
#  ('Taiwan', 'NNP'),
#  ('has', 'VBZ'),
#  ('been', 'VBN'),
#  ('generating', 'VBG'),
#  ('a', 'DT'),
#  ('lot', 'NN'),
#  ('of', 'IN'),
#  ('excitement', 'NN'),
#  ('in', 'IN'),
#  ('the', 'DT'),
#  ('region', 'NN'),
#  ('for', 'IN'),
#  ('LGBT', 'NNP'),
#  ('activists', 'NNS'),
#  (',', ','),
#  ('including', 'VBG'),
#  ('ones', 'NNS'),
#  ('in', 'IN'),
#  ('mainland', 'JJ'),
#  ('China', 'NNP'),
#  ('and', 'CC'),
#  ('Hong', 'NNP'),
#  ('Kong', 'NNP'),
#  (',', ','),
#  ('where', 'WRB'),
#  ('the', 'DT'),
#  ('possibility', 'NN'),
#  ('of', 'IN'),
#  ('it', 'PRP'),
#  ('being', 'VBG'),
#  ('legalized', 'VBN'),
#  ('will', 'MD'),
#  ('generate', 'VB'),
#  ('pressure', 'NN'),
#  ('for', 'IN'),
#  ('other', 'JJ'),
#  ('governments', 'NNS'),
#  ('in', 'IN'),
#  ('the', 'DT'),
#  ('region', 'NN'),
#  ('to', 'TO'),
#  ('follow', 'VB'),
#  (',', ','),
#  ("''", "''"),
#  ('she', 'PRP'),
#  ('told', 'VBD'),
#  ('CNN', 'NNP'),
#  ('.', '.'),
#  ('Many', 'NNP'),
#  ('of', 'IN'),
#  ('Taiwan', 'NNP'),
#  ("'s", 'POS'),
#  ('neighbors', 'NNS'),
#  ('in', 'IN'),
#  ('Asia', 'NNP'),
#  ('are', 'VBP'),
#  ('regressing', 'VBG'),
#  ('in', 'IN'),
#  ('their', 'PRP$'),
#  ('recognition', 'NN'),
#  ('of', 'IN'),
#  ('LGBT', 'NNP'),
#  ('people', 'NNS'),
#  ('.', '.'),
#  ('In', 'IN'),
#  ('Indonesia', 'NNP'),
#  (',', ','),
#  ('declining', 'VBG'),
#  ('secularism', 'NN'),
#  ('has', 'VBZ'),
#  ('led', 'VBN'),
#  ('to', 'TO'),
#  ('deepening', 'VBG'),
#  ('discrimination', 'NN'),
#  ('against', 'IN'),
#  ('the', 'DT'),
#  ('country', 'NN'),
#  ("'s", 'POS'),
#  ('gay', 'NN'),
#  (',', ','),
#  ('lesbian', 'JJ'),
#  ('and', 'CC'),
#  ('transgender', 'JJ'),
#  ('communities', 'NNS'),
#  ('.', '.'),
#  ('Earlier', 'RBR'),
#  ('this', 'DT'),
#  ('year', 'NN'),
#  ('there', 'RB'),
#  ('was', 'VBD'),
#  ('even', 'RB'),
#  ('the', 'DT'),
#  ('suggestion', 'NN'),
#  ('of', 'IN'),
#  ('a', 'DT'),
#  ('possible', 'JJ'),
#  ('ban', 'NN'),
#  ('on', 'IN'),
#  ('same-sex', 'JJ'),
#  ('relations', 'NNS'),
#  ('in', 'IN'),
#  ('the', 'DT'),
#  ('country', 'NN'),
#  ('.', '.'),
#  ('While', 'IN'),
#  ('Indonesia', 'NNP'),
#  ('is', 'VBZ'),
#  ('one', 'CD'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('more', 'RBR'),
#  ('serious', 'JJ'),
#  ('examples', 'NNS'),
#  (',', ','),
#  ('Malaysia', 'NNP'),
#  ('and', 'CC'),
#  ('the', 'DT'),
#  ('Philippines', 'NNPS'),
#  ('are', 'VBP'),
#  ('also', 'RB'),
#  ('following', 'VBG'),
#  ('its', 'PRP$'),
#  ('lead', 'NN'),
#  ('.', '.'),
#  ('In', 'IN'),
#  ('September', 'NNP'),
#  (',', ','),
#  ('two', 'CD'),
#  ('Malaysian', 'JJ'),
#  ('women', 'NNS'),
#  ('were', 'VBD'),
#  ('publicly', 'RB'),
#  ('caned', 'VBN'),
#  ('for', 'IN'),
#  ('attempting', 'VBG'),
#  ('to', 'TO'),
#  ('have', 'VB'),
#  ('sex', 'NN'),
#  ('in', 'IN'),
#  ('a', 'DT'),
#  ('parked', 'JJ'),
#  ('car', 'NN'),
#  (',', ','),
#  ('the', 'DT'),
#  ('first', 'JJ'),
#  ('time', 'NN'),
#  ('a', 'DT'),
#  ('punishment', 'NN'),
#  ('of', 'IN'),
#  ('its', 'PRP$'),
#  ('kind', 'NN'),
#  ('has', 'VBZ'),
#  ('been', 'VBN'),
#  ('imposed', 'VBN'),
#  ('in', 'IN'),
#  ('the', 'DT'),
#  ('country', 'NN'),
#  ('.', '.'),
#  ('In', 'IN'),
#  ('the', 'DT'),
#  ('Philippines', 'NNPS'),
#  (',', ','),
#  ('President', 'NNP'),
#  ('Rodrigo', 'NNP'),
#  ('Duterte', 'NNP'),
#  ('has', 'VBZ'),
#  ('said', 'VBD'),
#  ('he', 'PRP'),
#  ('would', 'MD'),
#  ('protect', 'VB'),
#  ('LGBT', 'NNP'),
#  ('rights', 'NNS'),
#  ('in', 'IN'),
#  ('the', 'DT'),
#  ('country', 'NN'),
#  ('but', 'CC'),
#  ('it', 'PRP'),
#  ('came', 'VBD'),
#  ('not', 'RB'),
#  ('long', 'RB'),
#  ('after', 'IN'),
#  ('he', 'PRP'),
#  ('hurled', 'VBD'),
#  ('one', 'CD'),
#  ('of', 'IN'),
#  ('his', 'PRP$'),
#  ('characteristic', 'JJ'),
#  ('insults', 'NNS'),
#  (',', ','),
#  ('calling', 'VBG'),
#  ('a', 'DT'),
#  ('US', 'NNP'),
#  ('ambassador', 'NN'),
#  ('a', 'DT'),
#  ('``', '``'),
#  ('gay', 'JJ'),
#  ...]

# %% [markdown]
# 自訂名詞片語 NP = 冠詞 DT + 任意數量的形容詞 JJ + 名詞 NN

# %%
pattern = 'NP: {<DT>?<JJ>*<NN>}'
cp = nltk.RegexpParser(pattern)
cs = cp.parse(sent)
print(cs)
# Out:
# (S
#   Taiwan/NNP
#   voters/NNS
#   reject/VBP
#   (NP same-sex/JJ marriage/NN)
#   By/IN
#   Hira/NNP
#   Humayun/NNP
#   and/CC
#   Susannah/NNP
#   Cullinane/NNP
#   Updated/VBD
#   0801/CD
#   GMT/NNP
#   (/(
#   1601/CD
#   HKT/NNP
#   )/)
#   November/NNP
#   25/CD
#   ,/,
#   2018/CD
#   Same-sex/JJ
#   activists/NNS
#   hug/VBD
#   outside/IN
#   (NP the/DT parliament/NN)
#   in/IN
#   Taipei/NNP
#   on/IN
#   May/NNP
#   24/CD
#   ,/,
#   2017/CD
#   as/IN
#   they/PRP
#   celebrate/VBP
#   (NP the/DT landmark/NN)
#   (NP decision/NN)
#   paving/VBG
#   (NP the/DT way/NN)
#   for/IN
#   (NP the/DT island/NN)
#   to/TO
#   become/VB
#   (NP the/DT first/JJ place/NN)
#   in/IN
#   Asia/NNP
#   to/TO
#   legalise/VB
#   (NP gay/JJ marriage/NN)
#   ./.
#   Crowds/NNP
#   of/IN
#   (NP pro-gay/JJ marriage/NN)
#   supporters/NNS
#   in/IN
#   Taiwan/NNP
#   on/IN
#   May/NNP
#   24/CD
#   cheered/VBD
#   ,/,
#   hugged/VBD
#   and/CC
#   wept/VBD
#   as/IN
#   (NP a/DT top/JJ court/NN)
#   ruled/VBD
#   in/IN
#   (NP favour/NN)
#   of/IN
#   same-sex/JJ
#   unions/NNS
#   ./.
#   //JJ
#   AFP/NNP
#   PHOTO/NNP
#   //NNP
#   SAM/NNP
#   YEH/NNP
#   (/(
#   Photo/NNP
#   (NP credit/NN)
#   should/MD
#   read/VB
#   SAM/NNP
#   YEH/AFP/Getty/NNP
#   Images/NNP
#   )/)
#   Three/NNP
#   (NP referendum/NN)
#   questions/NNS
#   initiated/VBN
#   by/IN
#   groups/NNS
#   that/WDT
#   opposed/VBD
#   (NP marriage/NN)
#   (NP equality/NN)
#   passed/VBD
#   ,/,
#   while/IN
#   those/DT
#   put/VBN
#   forth/RB
#   by/IN
#   (NP same-sex/JJ marriage/NN)
#   advocates/NNS
#   did/VBD
#   not/RB
#   ./.
#   For/IN
#   (NP instance/NN)
#   ,/,
#   (NP the/DT majority/NN)
#   (NP vote/NN)
#   was/VBD
#   yes/RB
#   on/IN
#   (NP a/DT question/NN)
#   that/WDT
#   asked/VBD
#   ,/,
#   ``/``
#   Do/VBP
#   you/PRP
#   agree/VB
#   that/IN
#   Civil/NNP
#   Code/NNP
#   regulations/NNS
#   should/MD
#   restrict/VB
#   (NP marriage/NN)
#   to/TO
#   being/VBG
#   between/IN
#   (NP a/DT man/NN)
#   and/CC
#   (NP a/DT woman/NN)
#   ?/.
#   ''/''
#   Voters/NNPS
#   ,/,
#   meanwhile/RB
#   ,/,
#   rejected/VBD
#   (NP a/DT question/NN)
#   put/VBD
#   (NP forth/NN)
#   by/IN
#   LGBT/NNP
#   activists/NNS
#   that/WDT
#   asked/VBD
#   if/IN
#   (NP civil/JJ code/NN)
#   (NP marriage/NN)
#   regulations/NNS
#   ``/``
#   should/MD
#   be/VB
#   used/VBN
#   to/TO
#   guarantee/VB
#   the/DT
#   rights/NNS
#   of/IN
#   (NP same-sex/NN)
#   couples/NNS
#   to/TO
#   get/VB
#   married/JJ
#   ./.
#   ''/''
#   Amnesty/NNP
#   International/NNP
#   Taiwan/NNP
#   's/POS
#   Acting/NNP
#   Director/NNP
#   Annie/NNP
#   Huang/NNP
#   called/VBD
#   (NP the/DT result/NN)
#   ``/``
#   (NP a/DT bitter/JJ blow/NN)
#   and/CC
#   (NP a/DT step/NN)
#   backwards/NNS
#   for/IN
#   human/JJ
#   rights/NNS
#   ''/''
#   on/IN
#   (NP the/DT island/NN)
#   ./.
#   ``/``
#   However/RB
#   ,/,
#   despite/IN
#   (NP this/DT setback/NN)
#   ,/,
#   we/PRP
#   remain/VBP
#   confident/JJ
#   that/IN
#   (NP love/NN)
#   and/CC
#   (NP equality/NN)
#   will/MD
#   ultimately/RB
#   prevail/VB
#   ,/,
#   ''/''
#   Huang/NNP
#   said/VBD
#   in/IN
#   (NP a/DT statement/NN)
#   ./.
#   ``/``
#   (NP The/DT result/NN)
#   must/MD
#   not/RB
#   be/VB
#   used/VBN
#   as/IN
#   (NP an/DT excuse/NN)
#   to/TO
#   further/JJ
#   undermine/VB
#   the/DT
#   rights/NNS
#   of/IN
#   LGBTI/NNP
#   people/NNS
#   ./.
#   (NP The/DT Taiwanese/JJ government/NN)
#   needs/NNS
#   to/TO
#   step/VB
#   up/RB
#   and/CC
#   take/VB
#   all/DT
#   necessary/JJ
#   measures/NNS
#   to/TO
#   deliver/VB
#   (NP equality/NN)
#   and/CC
#   (NP dignity/NN)
#   for/IN
#   all/DT
#   ,/,
#   regardless/RB
#   of/IN
#   who/WP
#   people/NNS
#   love/VBP
#   ./.
#   ''/''
#   (NP High/JJ court/NN)
#   ruled/VBD
#   in/IN
#   (NP favor/NN)
#   of/IN
#   (NP same-sex/JJ marriage/NN)
#   (NP The/DT vote/NN)
#   comes/VBZ
#   after/IN
#   Taiwan/NNP
#   's/POS
#   (NP high/JJ court/NN)
#   passed/VBD
#   (NP a/DT resolution/NN)
#   in/IN
#   May/NNP
#   2017/CD
#   ruling/VBG
#   it/PRP
#   was/VBD
#   unconstitutional/JJ
#   to/TO
#   ban/VB
#   same-sex/JJ
#   couples/NNS
#   from/IN
#   getting/VBG
#   married/VBN
#   ./.
#   (NP The/DT ruling/NN)
#   was/VBD
#   seen/VBN
#   as/IN
#   (NP a/DT rare/JJ beam/NN)
#   of/IN
#   (NP light/NN)
#   in/IN
#   (NP a/DT region/NN)
#   infamous/JJ
#   for/IN
#   its/PRP$
#   (NP repression/NN)
#   of/IN
#   LGBT/NNP
#   people/NNS
#   ./.
#   (NP The/DT ruling/NN)
#   gave/VBD
#   Taiwanese/JJ
#   lawmakers/NNS
#   (NP a/DT two-year/JJ deadline/NN)
#   to/TO
#   enshrine/VB
#   (NP marriage/NN)
#   (NP equality/NN)
#   into/IN
#   (NP law/NN)
#   ,/,
#   but/CC
#   (NP the/DT government/NN)
#   reached/VBD
#   (NP a/DT deadlock/NN)
#   ./.
#   With/IN
#   (NP the/DT government/NN)
#   (NP stuck/NN)
#   ,/,
#   Taiwan/NNP
#   's/POS
#   conservatives/NNS
#   saw/VBD
#   (NP an/DT opportunity/NN)
#   to/TO
#   use/VB
#   the/DT
#   newly/RB
#   revised/VBN
#   (NP referendum/NN)
#   (NP law/NN)
#   --/:
#   under/IN
#   which/WDT
#   any/DT
#   suggested/VBD
#   (NP question/NN)
#   that/IN
#   gets/VBZ
#   (NP a/DT minimum/NN)
#   of/IN
#   280,000/CD
#   signatures/NNS
#   must/MD
#   be/VB
#   put/VBN
#   to/TO
#   the/DT
#   people/NNS
#   --/:
#   to/TO
#   stall/VB
#   (NP same-sex/JJ marriage/NN)
#   ./.
#   Legal/NNP
#   (NP confusion/NN)
#   Saturday/NNP
#   's/POS
#   results/NNS
#   mean/VBP
#   that/IN
#   Taiwan/NNP
#   's/POS
#   (NP government/NN)
#   could/MD
#   now/RB
#   be/VB
#   compelled/VBN
#   to/TO
#   enforce/VB
#   (NP a/DT law/NN)
#   already/RB
#   ruled/VBD
#   unconstitutional/JJ
#   ./.
#   Further/RBR
#   complicating/VBG
#   matters/NNS
#   ,/,
#   there/EX
#   remains/VBZ
#   (NP broad/JJ disagreement/NN)
#   among/IN
#   legal/JJ
#   experts/NNS
#   on/IN
#   whether/IN
#   President/NNP
#   Tsai/NNP
#   Ing-wen/NNP
#   's/POS
#   (NP administration/NN)
#   is/VBZ
#   mandated/VBN
#   to/TO
#   enact/VB
#   (NP the/DT result/NN)
#   into/IN
#   (NP law/NN)
#   ./.
#   One/CD
#   (NP lawmaker/NN)
#   from/IN
#   (NP the/DT president/NN)
#   's/POS
#   Democratic/NNP
#   Progressive/NNP
#   Party/NNP
#   told/VBD
#   CNN/NNP
#   (NP any/DT positive/JJ result/NN)
#   ``/``
#   must/MD
#   pass/VB
#   ''/''
#   in/IN
#   (NP the/DT next/JJ legislative/JJ session/NN)
#   ,/,
#   but/CC
#   (NP a/DT legal/JJ expert/NN)
#   insisted/VBD
#   it/PRP
#   was/VBD
#   ``/``
#   up/RB
#   to/TO
#   lawmakers/NNS
#   ''/''
#   how/WRB
#   they/PRP
#   dealt/VBP
#   with/IN
#   (NP the/DT result/NN)
#   ./.
#   Amnesty/NNP
#   's/POS
#   (NP regional/JJ campaign/NN)
#   (NP manager/NN)
#   for/IN
#   Taiwan/NNP
#   Suki/NNP
#   Chung/NNP
#   said/VBD
#   (NP the/DT result/NN)
#   should/MD
#   not/RB
#   be/VB
#   used/VBN
#   to/TO
#   undermine/VB
#   LGBT/NNP
#   rights/NNS
#   ./.
#   ``/``
#   (NP The/DT government/NN)
#   must/MD
#   legislate/VB
#   for/IN
#   (NP equality/NN)
#   of/IN
#   (NP marriage/NN)
#   by/IN
#   2019/CD
#   to/TO
#   comply/VB
#   with/IN
#   the/DT
#   Constitutional/NNP
#   Court/NNP
#   's/POS
#   (NP decision/NN)
#   ,/,
#   ''/''
#   Chung/NNP
#   said/VBD
#   on/IN
#   Twitter/NNP
#   ./.
#   Suki/NNP
#   Chung/NNP
#   (NP The/DT result/NN)
#   is/VBZ
#   (NP a/DT bitter/JJ blow/NN)
#   but/CC
#   it/PRP
#   shouldn/VBZ
#   (NP ’/JJ t/NN)
#   be/VB
#   used/VBN
#   as/IN
#   (NP an/DT excuse/NN)
#   to/TO
#   further/JJ
#   undermine/VB
#   the/DT
#   rights/NNS
#   of/IN
#   #/#
#   LGBTI/NNP
#   people/NNS
#   ./.
#   (NP The/DT government/NN)
#   must/MD
#   legislate/VB
#   for/IN
#   (NP equality/NN)
#   of/IN
#   (NP marriage/NN)
#   by/IN
#   2019/CD
#   to/TO
#   comply/VB
#   with/IN
#   the/DT
#   Constitutional/NNP
#   Court/NNP
#   ’/NNP
#   s/POS
#   (NP decision/NN)
#   #/#
#   (NP taiwanelection/NN)
#   (NP https/NN)
#   :/:
#   //www.amnesty.org/en/latest/news/2018/11/taiwan-referendum-lgbti//JJ
#   …/NNS
#   Referendum/NNP
#   results/NNS
#   rejecting/VBG
#   (NP marriage/NN)
#   (NP equality/NN)
#   in/IN
#   Taiwan/NNP
#   a/DT
#   “/NNP
#   (NP bitter/NN)
#   (NP blow/NN)
#   (NP ”/NN)
#   Backwards/NNP
#   (NP step/NN)
#   for/IN
#   human/JJ
#   rights/NNS
#   as/IN
#   voters/NNS
#   reject/VBP
#   (NP same-sex/JJ marriage/NN)
#   rights/NNS
#   and/CC
#   (NP LGBTI-inclusive/JJ education/NN)
#   (NP The/DT director/NN)
#   of/IN
#   Human/NNP
#   Rights/NNP
#   Watch/NNP
#   's/POS
#   LGBT/NNP
#   rights/NNS
#   (NP program/NN)
#   ,/,
#   Graeme/NNP
#   Reid/NNP
#   ,/,
#   also/RB
#   called/VBD
#   for/IN
#   (NP the/DT legislation/NN)
#   to/TO
#   be/VB
#   enacted/VBN
#   ./.
#   ``/``
#   (NP Disappointing/JJ measure/NN)
#   of/IN
#   (NP public/JJ opinion/NN)
#   in/IN
#   #/#
#   Taiwan/NNP
#   (NP referendum/NN)
#   does/VBZ
#   not/RB
#   absolve/VB
#   lawmakers/NNS
#   from/IN
#   enacting/VBG
#   (NP legislation/NN)
#   -/:
#   per/IN
#   Constitutional/NNP
#   Court/NNP
#   ruling/VBG
#   -/:
#   to/TO
#   allow/VB
#   same-sex/JJ
#   partners/NNS
#   to/TO
#   marry/VB
#   ,/,
#   ''/''
#   Reid/NNP
#   tweeted/VBD
#   ./.
#   (NP Anti-gay/JJ marriage/NN)
#   groups/NNS
#   win/VBP
#   Taiwan/NNP
#   (NP referendum/NN)
#   (NP battle/NN)
#   Voters/NNP
#   in/IN
#   Taiwan/NNP
#   backed/VBD
#   (NP anti-gay/JJ marriage/NN)
#   referendums/NNS
#   Saturday/NNP
#   in/IN
#   what/WP
#   LGBT/NNP
#   activists/NNS
#   said/VBD
#   was/VBD
#   (NP a/DT major/JJ blow/NN)
#   to/TO
#   (NP the/DT island/NN)
#   's/POS
#   (NP reputation/NN)
#   as/IN
#   a/DT
#   rights/NNS
#   (NP trailblazer/NN)
#   ./.
#   Asia/NNP
#   's/POS
#   LGBT/NNP
#   (NP crisis/NN)
#   Taiwan/NNP
#   is/VBZ
#   home/VBN
#   to/TO
#   one/CD
#   of/IN
#   Asia/NNP
#   's/POS
#   largest/JJS
#   and/CC
#   most/RBS
#   (NP vibrant/JJ gay/NN)
#   communities/NNS
#   ./.
#   Many/JJ
#   of/IN
#   its/PRP$
#   citizens/NNS
#   take/VBP
#   (NP great/JJ pride/NN)
#   in/IN
#   (NP the/DT island/NN)
#   's/POS
#   progressive/JJ
#   ,/,
#   LGBT-friendly/JJ
#   values/NNS
#   ./.
#   If/IN
#   it/PRP
#   had/VBD
#   approved/VBN
#   (NP same-sex/JJ marriage/NN)
#   ,/,
#   it/PRP
#   would/MD
#   have/VB
#   become/VBN
#   (NP the/DT first/JJ place/NN)
#   in/IN
#   Asia/NNP
#   to/TO
#   do/VB
#   so/RB
#   ./.
#   (NP Ahead/NN)
#   of/IN
#   (NP the/DT vote/NN)
#   ,/,
#   Human/NNP
#   Rights/NNP
#   Watch/NNP
#   (NP senior/JJ researcher/NN)
#   Maya/NNP
#   Wang/NNP
#   said/VBD
#   Taiwan/NNP
#   was/VBD
#   seen/VBN
#   as/IN
#   (NP an/DT inspiration/NN)
#   for/IN
#   LGBT/NNP
#   rights/NNS
#   activists/NNS
#   ./.
#   ``/``
#   What/WP
#   's/VBZ
#   happening/VBG
#   in/IN
#   Taiwan/NNP
#   has/VBZ
#   been/VBN
#   generating/VBG
#   (NP a/DT lot/NN)
#   of/IN
#   (NP excitement/NN)
#   in/IN
#   (NP the/DT region/NN)
#   for/IN
#   LGBT/NNP
#   activists/NNS
#   ,/,
#   including/VBG
#   ones/NNS
#   in/IN
#   mainland/JJ
#   China/NNP
#   and/CC
#   Hong/NNP
#   Kong/NNP
#   ,/,
#   where/WRB
#   (NP the/DT possibility/NN)
#   of/IN
#   it/PRP
#   being/VBG
#   legalized/VBN
#   will/MD
#   generate/VB
#   (NP pressure/NN)
#   for/IN
#   other/JJ
#   governments/NNS
#   in/IN
#   (NP the/DT region/NN)
#   to/TO
#   follow/VB
#   ,/,
#   ''/''
#   she/PRP
#   told/VBD
#   CNN/NNP
#   ./.
#   Many/NNP
#   of/IN
#   Taiwan/NNP
#   's/POS
#   neighbors/NNS
#   in/IN
#   Asia/NNP
#   are/VBP
#   regressing/VBG
#   in/IN
#   their/PRP$
#   (NP recognition/NN)
#   of/IN
#   LGBT/NNP
#   people/NNS
#   ./.
#   In/IN
#   Indonesia/NNP
#   ,/,
#   declining/VBG
#   (NP secularism/NN)
#   has/VBZ
#   led/VBN
#   to/TO
#   deepening/VBG
#   (NP discrimination/NN)
#   against/IN
#   (NP the/DT country/NN)
#   's/POS
#   (NP gay/NN)
#   ,/,
#   lesbian/JJ
#   and/CC
#   transgender/JJ
#   communities/NNS
#   ./.
#   Earlier/RBR
#   (NP this/DT year/NN)
#   there/RB
#   was/VBD
#   even/RB
#   (NP the/DT suggestion/NN)
#   of/IN
#   (NP a/DT possible/JJ ban/NN)
#   on/IN
#   same-sex/JJ
#   relations/NNS
#   in/IN
#   (NP the/DT country/NN)
#   ./.
#   While/IN
#   Indonesia/NNP
#   is/VBZ
#   one/CD
#   of/IN
#   the/DT
#   more/RBR
#   serious/JJ
#   examples/NNS
#   ,/,
#   Malaysia/NNP
#   and/CC
#   the/DT
#   Philippines/NNPS
#   are/VBP
#   also/RB
#   following/VBG
#   its/PRP$
#   (NP lead/NN)
#   ./.
#   In/IN
#   September/NNP
#   ,/,
#   two/CD
#   Malaysian/JJ
#   women/NNS
#   were/VBD
#   publicly/RB
#   caned/VBN
#   for/IN
#   attempting/VBG
#   to/TO
#   have/VB
#   (NP sex/NN)
#   in/IN
#   (NP a/DT parked/JJ car/NN)
#   ,/,
#   (NP the/DT first/JJ time/NN)
#   (NP a/DT punishment/NN)
#   of/IN
#   its/PRP$
#   (NP kind/NN)
#   has/VBZ
#   been/VBN
#   imposed/VBN
#   in/IN
#   (NP the/DT country/NN)
#   ./.
#   In/IN
#   the/DT
#   Philippines/NNPS
#   ,/,
#   President/NNP
#   Rodrigo/NNP
#   Duterte/NNP
#   has/VBZ
#   said/VBD
#   he/PRP
#   would/MD
#   protect/VB
#   LGBT/NNP
#   rights/NNS
#   in/IN
#   (NP the/DT country/NN)
#   but/CC
#   it/PRP
#   came/VBD
#   not/RB
#   long/RB
#   after/IN
#   he/PRP
#   hurled/VBD
#   one/CD
#   of/IN
#   his/PRP$
#   characteristic/JJ
#   insults/NNS
#   ,/,
#   calling/VBG
#   a/DT
#   US/NNP
#   (NP ambassador/NN)
#   a/DT
#   ``/``
#   (NP gay/JJ son/NN)
#   of/IN
#   (NP a/DT bitch/NN)
#   ./.
#   ''/''
#   In/IN
#   mainland/JJ
#   China/NNP
#   ,/,
#   where/WRB
#   (NP homosexuality/NN)
#   is/VBZ
#   legal/JJ
#   but/CC
#   prejudices/NNS
#   and/CC
#   (NP discrimination/NN)
#   against/IN
#   LGBT/NNP
#   people/NNS
#   persist/VBP
#   under/IN
#   Communist/NNP
#   Party/NNP
#   (NP rule/NN)
#   ,/,
#   (NP an/DT author/NN)
#   of/IN
#   (NP same-sex/JJ erotic/JJ fiction/NN)
#   was/VBD
#   sent/VBN
#   to/TO
#   jail/VB
#   for/IN
#   10/CD
#   years/NNS
#   in/IN
#   November/NNP
#   ./.
#   Campaign/NNP
#   against/IN
#   (NP gay/JJ marriage/NN)
#   Gay/NNP
#   and/CC
#   lesbian/JJ
#   groups/NNS
#   in/IN
#   Taiwan/NNP
#   claimed/VBD
#   (NP a/DT flood/NN)
#   of/IN
#   (NP deliberate/JJ disinformation/NN)
#   was/VBD
#   spread/VBN
#   to/TO
#   confuse/VB
#   the/DT
#   public/JJ
#   ahead/RB
#   of/IN
#   the/DT
#   Saturday/NNP
#   's/POS
#   (NP vote/NN)
#   ./.
#   (NP A/DT campaign/NN)
#   (NP budget/NN)
#   of/IN
#   more/JJR
#   than/IN
#   $/$
#   3.24/CD
#   million/CD
#   was/VBD
#   reportedly/RB
#   raised/VBN
#   by/IN
#   leading/VBG
#   (NP conservative/JJ group/NN)
#   the/DT
#   Alliance/NNP
#   for/IN
#   the/DT
#   Happiness/NNP
#   of/IN
#   the/DT
#   Next/JJ
#   Generation/NNP
#   ,/,
#   whose/WP$
#   advertisements/NNS
#   have/VBP
#   appeared/VBN
#   on/IN
#   billboards/NNS
#   and/CC
#   front/JJ
#   pages/NNS
#   of/IN
#   newspapers/NNS
#   ./.
#   Across/IN
#   social/JJ
#   media/NNS
#   ,/,
#   rumors/NNS
#   were/VBD
#   circulated/VBN
#   as/IN
#   to/TO
#   what/WP
#   could/MD
#   happen/VB
#   in/IN
#   Taiwan/NNP
#   if/IN
#   (NP same-sex/JJ marriage/NN)
#   became/VBD
#   legal/JJ
#   ,/,
#   including/VBG
#   false/JJ
#   reports/NNS
#   that/IN
#   other/JJ
#   places/NNS
#   that/WDT
#   have/VBP
#   passed/VBN
#   the/DT
#   laws/NNS
#   have/VBP
#   regretted/VBN
#   it/PRP
#   ./.)

# %%
tree1 = nltk.Tree('NP',['Alick'])
print(tree1)
tree2 = nltk.Tree('N',['Alick','Rabbit'])
print(tree2)
tree3 = nltk.Tree('S',[tree1,tree2])
print(tree3.label())
tree3.draw()
# Out:
# (NP Alick)
# (N Alick Rabbit)
# S

# %%
NER = ne_chunk(nltk.pos_tag(word_tokenize(strEx)), binary=False)

# %%
type(NER)
# Out:
# nltk.tree.Tree

# %%
print(NER)
# Out:
# (S
#   (GPE Taiwan/NNP)
#   voters/NNS
#   reject/VBP
#   same-sex/JJ
#   marriage/NN
#   By/IN
#   (PERSON Hira/NNP Humayun/NNP)
#   and/CC
#   (PERSON Susannah/NNP Cullinane/NNP)
#   Updated/VBD
#   0801/CD
#   GMT/NNP
#   (/(
#   1601/CD
#   HKT/NNP
#   )/)
#   November/NNP
#   25/CD
#   ,/,
#   2018/CD
#   Same-sex/JJ
#   activists/NNS
#   hug/VBD
#   outside/IN
#   the/DT
#   parliament/NN
#   in/IN
#   (GPE Taipei/NNP)
#   on/IN
#   May/NNP
#   24/CD
#   ,/,
#   2017/CD
#   as/IN
#   they/PRP
#   celebrate/VBP
#   the/DT
#   landmark/NN
#   decision/NN
#   paving/VBG
#   the/DT
#   way/NN
#   for/IN
#   the/DT
#   island/NN
#   to/TO
#   become/VB
#   the/DT
#   first/JJ
#   place/NN
#   in/IN
#   (GPE Asia/NNP)
#   to/TO
#   legalise/VB
#   gay/JJ
#   marriage/NN
#   ./.
#   Crowds/NNP
#   of/IN
#   pro-gay/JJ
#   marriage/NN
#   supporters/NNS
#   in/IN
#   (GPE Taiwan/NNP)
#   on/IN
#   May/NNP
#   24/CD
#   cheered/VBD
#   ,/,
#   hugged/VBD
#   and/CC
#   wept/VBD
#   as/IN
#   a/DT
#   top/JJ
#   court/NN
#   ruled/VBD
#   in/IN
#   favour/NN
#   of/IN
#   same-sex/JJ
#   unions/NNS
#   ./.
#   //JJ
#   (ORGANIZATION AFP/NNP)
#   PHOTO/NNP
#   //NNP
#   (ORGANIZATION SAM/NNP)
#   YEH/NNP
#   (/(
#   (ORGANIZATION Photo/NNP)
#   credit/NN
#   should/MD
#   read/VB
#   (ORGANIZATION SAM/NNP)
#   YEH/AFP/Getty/NNP
#   Images/NNP
#   )/)
#   Three/NNP
#   referendum/NN
#   questions/NNS
#   initiated/VBN
#   by/IN
#   groups/NNS
#   that/WDT
#   opposed/VBD
#   marriage/NN
#   equality/NN
#   passed/VBD
#   ,/,
#   while/IN
#   those/DT
#   put/VBN
#   forth/RB
#   by/IN
#   same-sex/JJ
#   marriage/NN
#   advocates/NNS
#   did/VBD
#   not/RB
#   ./.
#   For/IN
#   instance/NN
#   ,/,
#   the/DT
#   majority/NN
#   vote/NN
#   was/VBD
#   yes/RB
#   on/IN
#   a/DT
#   question/NN
#   that/WDT
#   asked/VBD
#   ,/,
#   ``/``
#   Do/VBP
#   you/PRP
#   agree/VB
#   that/IN
#   (PERSON Civil/NNP Code/NNP)
#   regulations/NNS
#   should/MD
#   restrict/VB
#   marriage/NN
#   to/TO
#   being/VBG
#   between/IN
#   a/DT
#   man/NN
#   and/CC
#   a/DT
#   woman/NN
#   ?/.
#   ''/''
#   Voters/NNPS
#   ,/,
#   meanwhile/RB
#   ,/,
#   rejected/VBD
#   a/DT
#   question/NN
#   put/VBD
#   forth/NN
#   by/IN
#   (ORGANIZATION LGBT/NNP)
#   activists/NNS
#   that/WDT
#   asked/VBD
#   if/IN
#   civil/JJ
#   code/NN
#   marriage/NN
#   regulations/NNS
#   ``/``
#   should/MD
#   be/VB
#   used/VBN
#   to/TO
#   guarantee/VB
#   the/DT
#   rights/NNS
#   of/IN
#   same-sex/NN
#   couples/NNS
#   to/TO
#   get/VB
#   married/JJ
#   ./.
#   ''/''
#   (PERSON Amnesty/NNP International/NNP Taiwan/NNP)
#   's/POS
#   Acting/NNP
#   Director/NNP
#   (PERSON Annie/NNP Huang/NNP)
#   called/VBD
#   the/DT
#   result/NN
#   ``/``
#   a/DT
#   bitter/JJ
#   blow/NN
#   and/CC
#   a/DT
#   step/NN
#   backwards/NNS
#   for/IN
#   human/JJ
#   rights/NNS
#   ''/''
#   on/IN
#   the/DT
#   island/NN
#   ./.
#   ``/``
#   However/RB
#   ,/,
#   despite/IN
#   this/DT
#   setback/NN
#   ,/,
#   we/PRP
#   remain/VBP
#   confident/JJ
#   that/IN
#   love/NN
#   and/CC
#   equality/NN
#   will/MD
#   ultimately/RB
#   prevail/VB
#   ,/,
#   ''/''
#   (PERSON Huang/NNP)
#   said/VBD
#   in/IN
#   a/DT
#   statement/NN
#   ./.
#   ``/``
#   The/DT
#   result/NN
#   must/MD
#   not/RB
#   be/VB
#   used/VBN
#   as/IN
#   an/DT
#   excuse/NN
#   to/TO
#   further/JJ
#   undermine/VB
#   the/DT
#   rights/NNS
#   of/IN
#   (ORGANIZATION LGBTI/NNP)
#   people/NNS
#   ./.
#   The/DT
#   (GPE Taiwanese/JJ)
#   government/NN
#   needs/NNS
#   to/TO
#   step/VB
#   up/RB
#   and/CC
#   take/VB
#   all/DT
#   necessary/JJ
#   measures/NNS
#   to/TO
#   deliver/VB
#   equality/NN
#   and/CC
#   dignity/NN
#   for/IN
#   all/DT
#   ,/,
#   regardless/RB
#   of/IN
#   who/WP
#   people/NNS
#   love/VBP
#   ./.
#   ''/''
#   (ORGANIZATION High/JJ)
#   court/NN
#   ruled/VBD
#   in/IN
#   favor/NN
#   of/IN
#   same-sex/JJ
#   marriage/NN
#   The/DT
#   vote/NN
#   comes/VBZ
#   after/IN
#   (GPE Taiwan/NNP)
#   's/POS
#   high/JJ
#   court/NN
#   passed/VBD
#   a/DT
#   resolution/NN
#   in/IN
#   May/NNP
#   2017/CD
#   ruling/VBG
#   it/PRP
#   was/VBD
#   unconstitutional/JJ
#   to/TO
#   ban/VB
#   same-sex/JJ
#   couples/NNS
#   from/IN
#   getting/VBG
#   married/VBN
#   ./.
#   The/DT
#   ruling/NN
#   was/VBD
#   seen/VBN
#   as/IN
#   a/DT
#   rare/JJ
#   beam/NN
#   of/IN
#   light/NN
#   in/IN
#   a/DT
#   region/NN
#   infamous/JJ
#   for/IN
#   its/PRP$
#   repression/NN
#   of/IN
#   (ORGANIZATION LGBT/NNP)
#   people/NNS
#   ./.
#   The/DT
#   ruling/NN
#   gave/VBD
#   (GPE Taiwanese/JJ)
#   lawmakers/NNS
#   a/DT
#   two-year/JJ
#   deadline/NN
#   to/TO
#   enshrine/VB
#   marriage/NN
#   equality/NN
#   into/IN
#   law/NN
#   ,/,
#   but/CC
#   the/DT
#   government/NN
#   reached/VBD
#   a/DT
#   deadlock/NN
#   ./.
#   With/IN
#   the/DT
#   government/NN
#   stuck/NN
#   ,/,
#   (GPE Taiwan/NNP)
#   's/POS
#   conservatives/NNS
#   saw/VBD
#   an/DT
#   opportunity/NN
#   to/TO
#   use/VB
#   the/DT
#   newly/RB
#   revised/VBN
#   referendum/NN
#   law/NN
#   --/:
#   under/IN
#   which/WDT
#   any/DT
#   suggested/VBD
#   question/NN
#   that/IN
#   gets/VBZ
#   a/DT
#   minimum/NN
#   of/IN
#   280,000/CD
#   signatures/NNS
#   must/MD
#   be/VB
#   put/VBN
#   to/TO
#   the/DT
#   people/NNS
#   --/:
#   to/TO
#   stall/VB
#   same-sex/JJ
#   marriage/NN
#   ./.
#   (PERSON Legal/NNP)
#   confusion/NN
#   Saturday/NNP
#   's/POS
#   results/NNS
#   mean/VBP
#   that/IN
#   (GPE Taiwan/NNP)
#   's/POS
#   government/NN
#   could/MD
#   now/RB
#   be/VB
#   compelled/VBN
#   to/TO
#   enforce/VB
#   a/DT
#   law/NN
#   already/RB
#   ruled/VBD
#   unconstitutional/JJ
#   ./.
#   Further/RBR
#   complicating/VBG
#   matters/NNS
#   ,/,
#   there/EX
#   remains/VBZ
#   broad/JJ
#   disagreement/NN
#   among/IN
#   legal/JJ
#   experts/NNS
#   on/IN
#   whether/IN
#   President/NNP
#   (PERSON Tsai/NNP Ing-wen/NNP)
#   's/POS
#   administration/NN
#   is/VBZ
#   mandated/VBN
#   to/TO
#   enact/VB
#   the/DT
#   result/NN
#   into/IN
#   law/NN
#   ./.
#   One/CD
#   lawmaker/NN
#   from/IN
#   the/DT
#   president/NN
#   's/POS
#   (ORGANIZATION Democratic/NNP)
#   Progressive/NNP
#   (PERSON Party/NNP)
#   told/VBD
#   (ORGANIZATION CNN/NNP)
#   any/DT
#   positive/JJ
#   result/NN
#   ``/``
#   must/MD
#   pass/VB
#   ''/''
#   in/IN
#   the/DT
#   next/JJ
#   legislative/JJ
#   session/NN
#   ,/,
#   but/CC
#   a/DT
#   legal/JJ
#   expert/NN
#   insisted/VBD
#   it/PRP
#   was/VBD
#   ``/``
#   up/RB
#   to/TO
#   lawmakers/NNS
#   ''/''
#   how/WRB
#   they/PRP
#   dealt/VBP
#   with/IN
#   the/DT
#   result/NN
#   ./.
#   (PERSON Amnesty/NNP)
#   's/POS
#   regional/JJ
#   campaign/NN
#   manager/NN
#   for/IN
#   (GPE Taiwan/NNP)
#   Suki/NNP
#   (PERSON Chung/NNP)
#   said/VBD
#   the/DT
#   result/NN
#   should/MD
#   not/RB
#   be/VB
#   used/VBN
#   to/TO
#   undermine/VB
#   (ORGANIZATION LGBT/NNP)
#   rights/NNS
#   ./.
#   ``/``
#   The/DT
#   government/NN
#   must/MD
#   legislate/VB
#   for/IN
#   equality/NN
#   of/IN
#   marriage/NN
#   by/IN
#   2019/CD
#   to/TO
#   comply/VB
#   with/IN
#   the/DT
#   (ORGANIZATION Constitutional/NNP Court/NNP)
#   's/POS
#   decision/NN
#   ,/,
#   ''/''
#   (PERSON Chung/NNP)
#   said/VBD
#   on/IN
#   Twitter/NNP
#   ./.
#   (PERSON Suki/NNP Chung/NNP)
#   The/DT
#   result/NN
#   is/VBZ
#   a/DT
#   bitter/JJ
#   blow/NN
#   but/CC
#   it/PRP
#   shouldn/VBZ
#   ’/JJ
#   t/NN
#   be/VB
#   used/VBN
#   as/IN
#   an/DT
#   excuse/NN
#   to/TO
#   further/JJ
#   undermine/VB
#   the/DT
#   rights/NNS
#   of/IN
#   #/#
#   (ORGANIZATION LGBTI/NNP)
#   people/NNS
#   ./.
#   The/DT
#   government/NN
#   must/MD
#   legislate/VB
#   for/IN
#   equality/NN
#   of/IN
#   marriage/NN
#   by/IN
#   2019/CD
#   to/TO
#   comply/VB
#   with/IN
#   the/DT
#   (ORGANIZATION Constitutional/NNP Court/NNP)
#   ’/NNP
#   s/POS
#   decision/NN
#   #/#
#   taiwanelection/NN
#   https/NN
#   :/:
#   //www.amnesty.org/en/latest/news/2018/11/taiwan-referendum-lgbti//JJ
#   …/NNS
#   Referendum/NNP
#   results/NNS
#   rejecting/VBG
#   marriage/NN
#   equality/NN
#   in/IN
#   (GPE Taiwan/NNP)
#   a/DT
#   “/NNP
#   bitter/NN
#   blow/NN
#   ”/NN
#   Backwards/NNP
#   step/NN
#   for/IN
#   human/JJ
#   rights/NNS
#   as/IN
#   voters/NNS
#   reject/VBP
#   same-sex/JJ
#   marriage/NN
#   rights/NNS
#   and/CC
#   LGBTI-inclusive/JJ
#   education/NN
#   The/DT
#   director/NN
#   of/IN
#   (ORGANIZATION Human/NNP Rights/NNP Watch/NNP)
#   's/POS
#   (ORGANIZATION LGBT/NNP)
#   rights/NNS
#   program/NN
#   ,/,
#   (PERSON Graeme/NNP Reid/NNP)
#   ,/,
#   also/RB
#   called/VBD
#   for/IN
#   the/DT
#   legislation/NN
#   to/TO
#   be/VB
#   enacted/VBN
#   ./.
#   ``/``
#   Disappointing/JJ
#   measure/NN
#   of/IN
#   public/JJ
#   opinion/NN
#   in/IN
#   #/#
#   (GPE Taiwan/NNP)
#   referendum/NN
#   does/VBZ
#   not/RB
#   absolve/VB
#   lawmakers/NNS
#   from/IN
#   enacting/VBG
#   legislation/NN
#   -/:
#   per/IN
#   (ORGANIZATION Constitutional/NNP)
#   Court/NNP
#   ruling/VBG
#   -/:
#   to/TO
#   allow/VB
#   same-sex/JJ
#   partners/NNS
#   to/TO
#   marry/VB
#   ,/,
#   ''/''
#   (PERSON Reid/NNP)
#   tweeted/VBD
#   ./.
#   Anti-gay/JJ
#   marriage/NN
#   groups/NNS
#   win/VBP
#   (GPE Taiwan/NNP)
#   referendum/NN
#   battle/NN
#   Voters/NNP
#   in/IN
#   (GPE Taiwan/NNP)
#   backed/VBD
#   anti-gay/JJ
#   marriage/NN
#   referendums/NNS
#   Saturday/NNP
#   in/IN
#   what/WP
#   (ORGANIZATION LGBT/NNP)
#   activists/NNS
#   said/VBD
#   was/VBD
#   a/DT
#   major/JJ
#   blow/NN
#   to/TO
#   the/DT
#   island/NN
#   's/POS
#   reputation/NN
#   as/IN
#   a/DT
#   rights/NNS
#   trailblazer/NN
#   ./.
#   (GPE Asia/NNP)
#   's/POS
#   (ORGANIZATION LGBT/NNP)
#   crisis/NN
#   (GPE Taiwan/NNP)
#   is/VBZ
#   home/VBN
#   to/TO
#   one/CD
#   of/IN
#   (GPE Asia/NNP)
#   's/POS
#   largest/JJS
#   and/CC
#   most/RBS
#   vibrant/JJ
#   gay/NN
#   communities/NNS
#   ./.
#   Many/JJ
#   of/IN
#   its/PRP$
#   citizens/NNS
#   take/VBP
#   great/JJ
#   pride/NN
#   in/IN
#   the/DT
#   island/NN
#   's/POS
#   progressive/JJ
#   ,/,
#   LGBT-friendly/JJ
#   values/NNS
#   ./.
#   If/IN
#   it/PRP
#   had/VBD
#   approved/VBN
#   same-sex/JJ
#   marriage/NN
#   ,/,
#   it/PRP
#   would/MD
#   have/VB
#   become/VBN
#   the/DT
#   first/JJ
#   place/NN
#   in/IN
#   (GPE Asia/NNP)
#   to/TO
#   do/VB
#   so/RB
#   ./.
#   Ahead/NN
#   of/IN
#   the/DT
#   vote/NN
#   ,/,
#   (PERSON Human/NNP Rights/NNP Watch/NNP)
#   senior/JJ
#   researcher/NN
#   (PERSON Maya/NNP Wang/NNP)
#   said/VBD
#   (GPE Taiwan/NNP)
#   was/VBD
#   seen/VBN
#   as/IN
#   an/DT
#   inspiration/NN
#   for/IN
#   (ORGANIZATION LGBT/NNP)
#   rights/NNS
#   activists/NNS
#   ./.
#   ``/``
#   What/WP
#   's/VBZ
#   happening/VBG
#   in/IN
#   (GPE Taiwan/NNP)
#   has/VBZ
#   been/VBN
#   generating/VBG
#   a/DT
#   lot/NN
#   of/IN
#   excitement/NN
#   in/IN
#   the/DT
#   region/NN
#   for/IN
#   (ORGANIZATION LGBT/NNP)
#   activists/NNS
#   ,/,
#   including/VBG
#   ones/NNS
#   in/IN
#   mainland/JJ
#   (GPE China/NNP)
#   and/CC
#   (GPE Hong/NNP Kong/NNP)
#   ,/,
#   where/WRB
#   the/DT
#   possibility/NN
#   of/IN
#   it/PRP
#   being/VBG
#   legalized/VBN
#   will/MD
#   generate/VB
#   pressure/NN
#   for/IN
#   other/JJ
#   governments/NNS
#   in/IN
#   the/DT
#   region/NN
#   to/TO
#   follow/VB
#   ,/,
#   ''/''
#   she/PRP
#   told/VBD
#   (ORGANIZATION CNN/NNP)
#   ./.
#   Many/NNP
#   of/IN
#   (GPE Taiwan/NNP)
#   's/POS
#   neighbors/NNS
#   in/IN
#   (GPE Asia/NNP)
#   are/VBP
#   regressing/VBG
#   in/IN
#   their/PRP$
#   recognition/NN
#   of/IN
#   (ORGANIZATION LGBT/NNP)
#   people/NNS
#   ./.
#   In/IN
#   (GPE Indonesia/NNP)
#   ,/,
#   declining/VBG
#   secularism/NN
#   has/VBZ
#   led/VBN
#   to/TO
#   deepening/VBG
#   discrimination/NN
#   against/IN
#   the/DT
#   country/NN
#   's/POS
#   gay/NN
#   ,/,
#   lesbian/JJ
#   and/CC
#   transgender/JJ
#   communities/NNS
#   ./.
#   Earlier/RBR
#   this/DT
#   year/NN
#   there/RB
#   was/VBD
#   even/RB
#   the/DT
#   suggestion/NN
#   of/IN
#   a/DT
#   possible/JJ
#   ban/NN
#   on/IN
#   same-sex/JJ
#   relations/NNS
#   in/IN
#   the/DT
#   country/NN
#   ./.
#   While/IN
#   (GPE Indonesia/NNP)
#   is/VBZ
#   one/CD
#   of/IN
#   the/DT
#   more/RBR
#   serious/JJ
#   examples/NNS
#   ,/,
#   (GPE Malaysia/NNP)
#   and/CC
#   the/DT
#   (ORGANIZATION Philippines/NNPS)
#   are/VBP
#   also/RB
#   following/VBG
#   its/PRP$
#   lead/NN
#   ./.
#   In/IN
#   September/NNP
#   ,/,
#   two/CD
#   (GPE Malaysian/JJ)
#   women/NNS
#   were/VBD
#   publicly/RB
#   caned/VBN
#   for/IN
#   attempting/VBG
#   to/TO
#   have/VB
#   sex/NN
#   in/IN
#   a/DT
#   parked/JJ
#   car/NN
#   ,/,
#   the/DT
#   first/JJ
#   time/NN
#   a/DT
#   punishment/NN
#   of/IN
#   its/PRP$
#   kind/NN
#   has/VBZ
#   been/VBN
#   imposed/VBN
#   in/IN
#   the/DT
#   country/NN
#   ./.
#   In/IN
#   the/DT
#   (ORGANIZATION Philippines/NNPS)
#   ,/,
#   President/NNP
#   (PERSON Rodrigo/NNP Duterte/NNP)
#   has/VBZ
#   said/VBD
#   he/PRP
#   would/MD
#   protect/VB
#   (ORGANIZATION LGBT/NNP)
#   rights/NNS
#   in/IN
#   the/DT
#   country/NN
#   but/CC
#   it/PRP
#   came/VBD
#   not/RB
#   long/RB
#   after/IN
#   he/PRP
#   hurled/VBD
#   one/CD
#   of/IN
#   his/PRP$
#   characteristic/JJ
#   insults/NNS
#   ,/,
#   calling/VBG
#   a/DT
#   (GPE US/NNP)
#   ambassador/NN
#   a/DT
#   ``/``
#   gay/JJ
#   son/NN
#   of/IN
#   a/DT
#   bitch/NN
#   ./.
#   ''/''
#   In/IN
#   mainland/JJ
#   (GPE China/NNP)
#   ,/,
#   where/WRB
#   homosexuality/NN
#   is/VBZ
#   legal/JJ
#   but/CC
#   prejudices/NNS
#   and/CC
#   discrimination/NN
#   against/IN
#   (ORGANIZATION LGBT/NNP)
#   people/NNS
#   persist/VBP
#   under/IN
#   (ORGANIZATION Communist/NNP Party/NNP)
#   rule/NN
#   ,/,
#   an/DT
#   author/NN
#   of/IN
#   same-sex/JJ
#   erotic/JJ
#   fiction/NN
#   was/VBD
#   sent/VBN
#   to/TO
#   jail/VB
#   for/IN
#   10/CD
#   years/NNS
#   in/IN
#   November/NNP
#   ./.
#   (PERSON Campaign/NNP)
#   against/IN
#   gay/JJ
#   marriage/NN
#   Gay/NNP
#   and/CC
#   lesbian/JJ
#   groups/NNS
#   in/IN
#   (GPE Taiwan/NNP)
#   claimed/VBD
#   a/DT
#   flood/NN
#   of/IN
#   deliberate/JJ
#   disinformation/NN
#   was/VBD
#   spread/VBN
#   to/TO
#   confuse/VB
#   the/DT
#   public/JJ
#   ahead/RB
#   of/IN
#   the/DT
#   Saturday/NNP
#   's/POS
#   vote/NN
#   ./.
#   A/DT
#   campaign/NN
#   budget/NN
#   of/IN
#   more/JJR
#   than/IN
#   $/$
#   3.24/CD
#   million/CD
#   was/VBD
#   reportedly/RB
#   raised/VBN
#   by/IN
#   leading/VBG
#   conservative/JJ
#   group/NN
#   the/DT
#   Alliance/NNP
#   for/IN
#   the/DT
#   (ORGANIZATION Happiness/NNP)
#   of/IN
#   the/DT
#   (ORGANIZATION Next/JJ Generation/NNP)
#   ,/,
#   whose/WP$
#   advertisements/NNS
#   have/VBP
#   appeared/VBN
#   on/IN
#   billboards/NNS
#   and/CC
#   front/JJ
#   pages/NNS
#   of/IN
#   newspapers/NNS
#   ./.
#   Across/IN
#   social/JJ
#   media/NNS
#   ,/,
#   rumors/NNS
#   were/VBD
#   circulated/VBN
#   as/IN
#   to/TO
#   what/WP
#   could/MD
#   happen/VB
#   in/IN
#   (GPE Taiwan/NNP)
#   if/IN
#   same-sex/JJ
#   marriage/NN
#   became/VBD
#   legal/JJ
#   ,/,
#   including/VBG
#   false/JJ
#   reports/NNS
#   that/IN
#   other/JJ
#   places/NNS
#   that/WDT
#   have/VBP
#   passed/VBN
#   the/DT
#   laws/NNS
#   have/VBP
#   regretted/VBN
#   it/PRP
#   ./.)

# %%
def get_continuous_chunks(text, label):
    chunked = ne_chunk(pos_tag(word_tokenize(text)))
    prev = None
    continuous_chunk = []
    current_chunk = []

    for subtree in chunked:
        if type(subtree) == Tree and subtree.label() == label:
            current_chunk.append(" ".join([token for token, pos in subtree.leaves()]))
        elif current_chunk:
            named_entity = " ".join(current_chunk)
            if named_entity not in continuous_chunk:
                continuous_chunk.append(named_entity)
                current_chunk = []
        else:
            continue

    return continuous_chunk

# %%
get_continuous_chunks(strEx, 'GPE')
# Out:
# ['Taiwan',
#  'Taipei',
#  'Asia',
#  'Taiwan Taiwanese',
#  'Taiwan Taiwanese Taiwan',
#  'Taiwan Taiwan',
#  'Taiwan Taiwan Taiwan',
#  'Taiwan Asia',
#  'Taiwan Asia Asia',
#  'Taiwan Taiwan China',
#  'Hong Kong',
#  'Taiwan Asia Indonesia',
#  'Indonesia',
#  'Malaysia',
#  'Malaysian',
#  'US',
#  'China']

# %%
get_continuous_chunks(strEx, 'ORGANIZATION')
# Out:
# ['AFP',
#  'SAM',
#  'Photo',
#  'SAM LGBT',
#  'LGBTI',
#  'High',
#  'LGBT',
#  'Democratic',
#  'CNN',
#  'LGBT Constitutional Court',
#  'LGBTI Constitutional Court',
#  'Human Rights Watch',
#  'LGBT Constitutional',
#  'LGBT LGBT',
#  'LGBT LGBT CNN',
#  'LGBT Philippines',
#  'Philippines',
#  'LGBT LGBT Communist Party',
#  'Happiness',
#  'Next Generation']
